# %% [markdown]
# ## LangChain How-to: Stream Runnables (Ollama)
#
# This notebook shows how to stream with LangChain runnables using local `ollama` models, and how to work with streaming events. We use these models served by `ollama`:
# - `deepseek-r1:8b`
# - `llama3.1:8b-instruct-q8_0`
# - `qwen2.5:7b-instruct`
#
# References:
# - LangChain How-to: Streaming (`python.langchain.com`) — see `Using Stream` and `Using Stream Events`.
# - Reference notebook: `streaming.ipynb` from the LangChain docs repository.
#
# Prerequisites:
# - `ollama` is running locally and the models are pulled: `ollama pull deepseek-r1:8b`, `ollama pull llama3.1:8b-instruct-q8_0`, `ollama pull qwen2.5:7b-instruct`
# - Python packages installed: `pip install -r requirements.txt`
#
# Tip:
# - You can switch models by changing the `MODEL` variable in the setup cell below.
# - Each section is broken into small steps with short runnable examples and plain-English explanations.

# %%
# Setup
# - Select an Ollama model by name
# - Import LangChain + langchain-ollama integrations
# - Quick utility to pretty-print streaming

# MODEL = "deepseek-r1:8b"  # change to: "llama3.1:8b-instruct-q8_0" or "qwen2.5:7b-instruct"
MODEL = "llama3.1:8b-instruct-q8_0" 

from typing import Iterable, Any

from langchain_ollama import ChatOllama
from langchain_core.messages import HumanMessage
from langchain_core.runnables import RunnableLambda


def print_stream(iterable: Iterable[Any]):
    """Print streaming chunks as they arrive, on one line."""
    for chunk in iterable:
        # Chunks from chat models are usually AIMessageChunks or strings
        print(getattr(chunk, "content", chunk), end="", flush=True)
    print()

# %% [markdown]
# ### Using Stream
#
# In this part, we stream the final outputs from runnables. We'll start with chat models (LLMs), then build simple chains, then show streamed inputs, and call out non-streaming components.

# %% [markdown]
# #### LLMs and Chat Models
#
# Small steps:
# 1) Create a `ChatOllama` chat model bound to your `ollama` instance
# 2) Stream a simple prompt token-by-token
# 3) Try switching `MODEL`
#
# Explanation:
# - `stream` yields chunks. For chat models, each chunk is an `AIMessageChunk` with `.content`.
# - Printing as chunks arrive makes UI responsive and reduces perceived latency.

# %%
chat = ChatOllama(model=MODEL, temperature=0.3)

print("Model:", MODEL)
print("Streaming response:\n")

print_stream(
    chat.stream([
        HumanMessage(content="Give a 1-sentence fun fact about Vietnamese coffee.")
    ])
)
# Out:
# Model: llama3.1:8b-instruct-q8_0
# Streaming response:
#
# In Vietnam, traditional coffee is often served over sweetened condensed milk in a small metal filter called a phin, which allows the coffee to drip slowly into the cup, creating a rich and creamy flavor experience known as "ca phe sua da".

# %% [markdown]
# #### Chains
#
# Small steps:
# 1) Build a simple prompt → chat chain with LCEL
# 2) Stream the chain output
# 3) Swap models and compare
#
# Explanation:
# - LCEL composes components with `|`. Here: `prompt | chat`.
# - `chain.stream(input_dict)` yields `AIMessageChunk`s reflecting the chain's final output.

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant."),
    ("human", "Translate to Vietnamese: {text}")
])

chain = prompt | chat

print_stream(chain.stream({"text": "Good morning!"}))
# Out:
# Chào buổi sáng!

# %% [markdown]
# #### Working with Input Streams
#
# Small steps:
# 1) Define a prompt that takes a single `input` field
# 2) Create an async generator that yields input chunks
# 3) Stream the chain output as the input arrives
#
# Explanation:
# - `chain.astream({...})` supports async iterables as values. The chain produces output chunks as soon as it has enough input to generate.
# - This is useful for partial-input UX like live dictation.

# %%
import asyncio
from typing import AsyncIterable

# Reuse chat and define a prompt that consumes {input}
stream_prompt = ChatPromptTemplate.from_messages([
    ("system", "You produce concise helpful answers."),
    ("human", "Summarize as I type: {input}")
])
stream_chain = stream_prompt | chat

async def input_chunks() -> AsyncIterable[str]:
    parts = ["Today ", "we explore ", "LangChain streaming."]
    for p in parts:
        await asyncio.sleep(0.2)
        yield p

async def demo_streaming_input():
    async for chunk in stream_chain.astream({"input": input_chunks()}):
        print(getattr(chunk, "content", chunk), end="", flush=True)
    print()

await demo_streaming_input()
# Out:
# An asynchronous generator object, likely from a library like `asyncio` or `aiohttp`, which is generating chunks of data. The `input_chunks` name suggests it's processing input data in batches.

# %% [markdown]
# #### Non-streaming components
#
# Small steps:
# 1) Create a synchronous `RunnableLambda` that does CPU-bound work (non-streaming)
# 2) Compose it before the chat model
# 3) Observe: the overall chain can't emit until the non-streaming step completes
#
# Explanation:
# - Non-streaming parts act like buffers in your pipeline; place them early and keep them fast.
# - If you must include them, prefer small/quick transforms before the streaming model.

# %%
import time

# Non-streaming CPU-bound transform

def slow_upper(text: str) -> str:
    time.sleep(1.0)  # simulate work
    return text.upper()

pre = RunnableLambda(lambda x: {"text": slow_upper(x["text"])})
non_stream_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are concise."),
    ("human", "Rewrite politely: {text}")
])
non_stream_chain = pre | non_stream_prompt | chat

print_stream(non_stream_chain.stream({"text": "give me a hint about Hanoi food"}))
# Out:
# Could you tell me a bit about the typical flavors or dishes I should try when visiting Hanoi?

# %% [markdown]
# ### Using Stream Events
#
# `astream_events` lets you observe start/end/stream events for each runnable in a graph. This is useful for tracing, live UIs, and debugging.

# %% [markdown]
# #### Event Reference
#
# Common event names include:
# - `on_chain_start`, `on_chain_stream`, `on_chain_end`
# - `on_chat_model_start`, `on_chat_model_stream`, `on_chat_model_end`
# - `on_tool_start`, `on_tool_end` (if using tools)
#
# We will print a compact view of events.

# %%
import json

MAX_LEN = 120

def _safe(obj):
    """Recursively convert event payloads to JSON-serializable primitives.
    - Strings are trimmed
    - Objects are stringified if not serializable
    - AI/Human/System message-like objects use their `content` if present
    """
    try:
        if isinstance(obj, dict):
            return {k: _safe(v) for k, v in obj.items()}
        if isinstance(obj, (list, tuple)):
            return [_safe(v) for v in obj]
        if isinstance(obj, str):
            return obj if len(obj) <= MAX_LEN else obj[:MAX_LEN] + "…"
        # Prefer `.content` if available (e.g., AIMessageChunk, HumanMessage)
        content = getattr(obj, "content", None)
        if isinstance(content, str):
            return _safe(content)
        # If it's already JSON-serializable, keep it
        json.dumps(obj)
        return obj
    except TypeError:
        rep = repr(obj)
        return rep if len(rep) <= MAX_LEN else rep[:MAX_LEN] + "…"


def show_event(e):
    name = e.get("event", e.get("name"))
    typ = e.get("type")
    meta = {k: v for k, v in e.items() if k in {"event", "name", "type", "tags", "RunName", "run_id"}}
    data = _safe(e.get("data"))
    print(json.dumps({"name": name, "type": typ, "meta": _safe(meta), "data": data}, ensure_ascii=False))

# %% [markdown]
# #### Chat Model
#
# Small steps:
# 1) Use `chat.astream_events` to observe token streaming
# 2) Print a filtered subset of fields for readability
#
# Explanation:
# - Events include model start, streamed tokens, and end. This is great for building real-time UIs.

# %%
async def events_for_chat():
    async for e in chat.astream_events(
        [HumanMessage(content="List 3 must-try foods in Hanoi.")],
        version="v1",
    ):
        show_event(e)

await events_for_chat()
# Out:
# {"name": "on_chat_model_start", "type": null, "meta": {"event": "on_chat_model_start", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "name": "ChatOllama", "tags": []}, "data": {"input": ["List 3 must-try foods in Hanoi."]}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "H"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "anoi"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ","}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " the"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " culinary"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " capital"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " of"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " Vietnam"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "!"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " Here"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " are"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " "}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "3"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " must"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "-"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "try"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " foods"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " when"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " visiting"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " H"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "anoi"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ":\n\n"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "1"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "."}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " **"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "B"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "ún"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " Ch"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "ả"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "**:"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " A"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " classic"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " H"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "anoi"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " dish"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " consisting"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " of"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " grilled"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " pork"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " served"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " with"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " rice"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " noodles"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " ("}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "b"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "ún"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ")"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " and"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " a"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " side"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " of"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " dipping"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " sauce"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " ("}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "ch"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "ả"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ")."}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " The"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " combination"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " of"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " tender"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " pork"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ","}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " crunchy"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " vegetables"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ","}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " and"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " flavorful"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " sauce"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " is"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " a"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " match"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " made"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " in"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " heaven"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ".\n"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "2"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "."}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " **"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "Ph"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "ở"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "**:"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " Vietnam"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "'s"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " national"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " dish"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " is"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " a"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " staple"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " in"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " H"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "anoi"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "."}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " This"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " popular"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " beef"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " nood"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "le"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " soup"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " is"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " made"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " with"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " slow"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "-co"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "oked"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " broth"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ","}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " rice"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " noodles"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ","}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " herbs"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ","}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " and"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " your"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " choice"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " of"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " beef"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " ("}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "r"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "are"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ","}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " well"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "-done"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ","}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " or"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " brisk"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "et"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ")."}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " Ph"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "ở"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " is"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " a"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " comforting"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " and"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " flavorful"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " experience"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " that"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " will"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " warm"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " your"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " belly"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " and"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " soul"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ".\n"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "3"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "."}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " **"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "B"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "ánh"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " M"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "ì"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "**:"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " A"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " Vietnamese"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " sandwich"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " that"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "'s"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " become"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " a"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " global"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " phenomenon"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "."}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " In"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " H"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "anoi"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ","}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " you"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " can"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " find"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " various"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " versions"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " of"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " bánh"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " m"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "ì"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ","}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " but"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " the"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " classic"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " combination"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " features"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " grilled"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " pork"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ","}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " pick"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "led"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " carrots"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " and"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " da"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "ikon"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ","}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " cil"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "antro"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ","}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " chili"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " sauce"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ","}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " and"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " may"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "onna"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "ise"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " on"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " a"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " crispy"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " bag"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "u"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "ette"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ".\n\n"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "These"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " three"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " dishes"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " are"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " must"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "-"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "try"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " experiences"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " in"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " H"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "anoi"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ","}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " and"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " you"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "'ll"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " find"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " them"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " at"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " local"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " eater"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "ies"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ","}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " street"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " food"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " stalls"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ","}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " or"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " markets"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " throughout"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " the"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " city"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "."}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " Enjoy"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " exploring"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " the"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " flavors"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " of"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": " H"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "anoi"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": "!"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": [], "name": "ChatOllama"}, "data": {"chunk": ""}}
# {"name": "on_chat_model_end", "type": null, "meta": {"event": "on_chat_model_end", "name": "ChatOllama", "run_id": "d2040078-7109-495d-bf34-c10b28707a5b", "tags": []}, "data": {"output": "Hanoi, the culinary capital of Vietnam! Here are 3 must-try foods when visiting Hanoi:\n\n1. **Bún Chả**: A classic Hanoi …"}}

# %%
# Bind the function tools and the structured tool together (use tool-capable model)
llm_with_tools = llm_tools.bind_tools(TOOLS_WITH_STRUCTURED)

query = "What is 3 * 12? Also, what is 11 + 49? And compute 2^10."
msg = llm_with_tools.invoke(query)

print("Model content:\n", msg.content)
print("\nTool calls:")
for i, tc in enumerate(getattr(msg, "tool_calls", []) or []):
    print(i, tc["name"], tc["args"])
# Out:
# Model content:
#
#
# Tool calls:
# 0 multiply {'a': 3, 'b': 12}
# 1 add {'a': 11, 'b': 49}
# 2 power {'base': 2, 'exponent': 10}

# %%
# Bind the function tools and the structured tool together (use tool-capable model)
llm_with_tools = llm_tools.bind_tools(TOOLS_WITH_STRUCTURED)

query = "What is 3 * 12? Also, what is 11 + 49? And compute 2^10."
msg = llm_with_tools.invoke(query)

print("Model content:\n", msg.content)
print("\nTool calls:")
for i, tc in enumerate(getattr(msg, "tool_calls", []) or []):
    print(i, tc["name"], tc["args"])
# Out:
# Model content:
#
#
# Tool calls:
# 0 multiply {'a': 3, 'b': 12}
# 1 add {'a': 11, 'b': 49}
# 2 power {'base': 2, 'exponent': 10}

# %%
# Bind the function tools and the structured tool together (use tool-capable model)
llm_with_tools = llm_tools.bind_tools(TOOLS_WITH_STRUCTURED)

query = "What is 3 * 12? Also, what is 11 + 49? And compute 2^10."
msg = llm_with_tools.invoke(query)

print("Model content:\n", msg.content)
print("\nTool calls:")
for i, tc in enumerate(getattr(msg, "tool_calls", []) or []):
    print(i, tc["name"], tc["args"])
# Out:
# Model content:
#
#
# Tool calls:
# 0 multiply {'a': 3, 'b': 12}
# 1 add {'a': 11, 'b': 49}
# 2 power {'base': 2, 'exponent': 10}

# %%
# Bind the function tools and the structured tool together (use tool-capable model)
llm_with_tools = llm_tools.bind_tools(TOOLS_WITH_STRUCTURED)

query = "What is 3 * 12? Also, what is 11 + 49? And compute 2^10."
msg = llm_with_tools.invoke(query)

print("Model content:\n", msg.content)
print("\nTool calls:")
for i, tc in enumerate(getattr(msg, "tool_calls", []) or []):
    print(i, tc["name"], tc["args"])
# Out:
# Model content:
#
#
# Tool calls:
# 0 multiply {'a': 3, 'b': 12}
# 1 add {'a': 11, 'b': 49}
# 2 power {'base': 2, 'exponent': 10}

# %% [markdown]
# #### Chain
#
# Small steps:
# 1) Observe events for a prompt → chat chain
# 2) Notice both chain-level and chat-model-level events
#
# Explanation:
# - Chain events wrap the model events; useful to see where latency accumulates.

# %%
async def events_for_chain():
    async for e in chain.astream_events({"text": "Good evening."}, version="v1"):
        show_event(e)

await events_for_chain()
# Out:
# {"name": "on_chain_start", "type": null, "meta": {"event": "on_chain_start", "run_id": "80fa44de-7243-4863-8b61-afe4c36707c2", "name": "RunnableSequence", "tags": []}, "data": {"input": {"text": "Good evening."}}}
# {"name": "on_prompt_start", "type": null, "meta": {"event": "on_prompt_start", "name": "ChatPromptTemplate", "run_id": "17c3a7cd-aee4-4f03-b87b-295c8b2cbd9f", "tags": ["seq:step:1"]}, "data": {"input": {"text": "Good evening."}}}
# {"name": "on_prompt_end", "type": null, "meta": {"event": "on_prompt_end", "name": "ChatPromptTemplate", "run_id": "17c3a7cd-aee4-4f03-b87b-295c8b2cbd9f", "tags": ["seq:step:1"]}, "data": {"input": {"text": "Good evening."}, "output": "ChatPromptValue(messages=[SystemMessage(content='You are a helpful assistant.', additional_kwargs={}, response_metadata=…"}}
# {"name": "on_chat_model_start", "type": null, "meta": {"event": "on_chat_model_start", "name": "ChatOllama", "run_id": "6cd4281e-a9c6-4a58-bbd8-ea7d94fc74fd", "tags": ["seq:step:2"]}, "data": {"input": {"messages": [["You are a helpful assistant.", "Translate to Vietnamese: Good evening."]]}}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "6cd4281e-a9c6-4a58-bbd8-ea7d94fc74fd", "tags": ["seq:step:2"]}, "data": {"chunk": "Ch"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "80fa44de-7243-4863-8b61-afe4c36707c2", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "Ch"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "6cd4281e-a9c6-4a58-bbd8-ea7d94fc74fd", "tags": ["seq:step:2"]}, "data": {"chunk": "ào"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "80fa44de-7243-4863-8b61-afe4c36707c2", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "ào"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "6cd4281e-a9c6-4a58-bbd8-ea7d94fc74fd", "tags": ["seq:step:2"]}, "data": {"chunk": " buổi"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "80fa44de-7243-4863-8b61-afe4c36707c2", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " buổi"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "6cd4281e-a9c6-4a58-bbd8-ea7d94fc74fd", "tags": ["seq:step:2"]}, "data": {"chunk": " tối"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "80fa44de-7243-4863-8b61-afe4c36707c2", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " tối"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "6cd4281e-a9c6-4a58-bbd8-ea7d94fc74fd", "tags": ["seq:step:2"]}, "data": {"chunk": "!"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "80fa44de-7243-4863-8b61-afe4c36707c2", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "!"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "6cd4281e-a9c6-4a58-bbd8-ea7d94fc74fd", "tags": ["seq:step:2"]}, "data": {"chunk": ""}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "80fa44de-7243-4863-8b61-afe4c36707c2", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": ""}}
# {"name": "on_chat_model_end", "type": null, "meta": {"event": "on_chat_model_end", "name": "ChatOllama", "run_id": "6cd4281e-a9c6-4a58-bbd8-ea7d94fc74fd", "tags": ["seq:step:2"]}, "data": {"input": {"messages": [["You are a helpful assistant.", "Translate to Vietnamese: Good evening."]]}, "output": {"generations": [[{"text": "Chào buổi tối!", "generation_info": {"model": "llama3.1:8b-instruct-q8_0", "created_at": "2025-08-19T12:32:12.373382Z", "done": true, "done_reason": "stop", "total_duration": 249755750, "load_duration": 26521583, "prompt_eval_count": 28, "prompt_eval_duration": 90551875, "eval_count": 6, "eval_duration": 132074584, "model_name": "llama3.1:8b-instruct-q8_0"}, "type": "ChatGenerationChunk", "message": "Chào buổi tối!"}]], "llm_output": null, "run": null, "type": "LLMResult"}}}
# {"name": "on_chain_end", "type": null, "meta": {"event": "on_chain_end", "name": "RunnableSequence", "run_id": "80fa44de-7243-4863-8b61-afe4c36707c2", "tags": []}, "data": {"output": "Chào buổi tối!"}}

# %% [markdown]
# #### Filtering Events
#
# Small steps:
# 1) Filter to only `on_chat_model_stream` to see token payloads
# 2) Show the token text
#
# Explanation:
# - This pattern reduces noise while keeping the live token stream visible.

# %%
async def only_token_stream():
    async for e in chat.astream_events(
        [HumanMessage(content="Name 3 popular Vietnamese desserts.")],
        version="v1",
    ):
        name = e.get("event", e.get("name"))
        if name == "on_chat_model_stream":
            data = e.get("data", {})
            chunk = data.get("chunk")
            token_text = getattr(chunk, "content", chunk)
            if token_text:
                print(token_text, end="", flush=True)
    print()

await only_token_stream()
# Out:
# Here are three popular Vietnamese desserts:
#
# 1. **Che**: A sweet soup made from various ingredients such as mung beans, tapioca pearls, and coconut milk.
# 2. **Banh Bot Loc**: Small, chewy dumplings filled with mung bean paste or other fillings, typically served in a sweet broth.
# 3. **Xoi Xeo**: Sticky rice cake topped with mung bean paste, coconut milk, and sesame seeds.
#
# These desserts are all popular in Vietnam and often enjoyed at street food stalls or traditional cafes.

# %% [markdown]
# #### Non-streaming components
#
# Small steps:
# 1) Add a non-streaming pre-processor before the chain
# 2) Observe events: no token stream until the pre-processor finishes
#
# Explanation:
# - You’ll see a gap between `on_chain_start` and `on_chat_model_start` proportional to your pre-processing time.

# %%
slow_pre = RunnableLambda(lambda x: {"text": slow_upper(x["text"])})
events_chain = slow_pre | prompt | chat

async def events_with_non_streaming():
    async for e in events_chain.astream_events({"text": "Hello from Saigon."}, version="v1"):
        show_event(e)

await events_with_non_streaming()
# Out:
# {"name": "on_chain_start", "type": null, "meta": {"event": "on_chain_start", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "name": "RunnableSequence", "tags": []}, "data": {"input": {"text": "Hello from Saigon."}}}
# {"name": "on_chain_start", "type": null, "meta": {"event": "on_chain_start", "name": "RunnableLambda", "run_id": "d9e0a1ec-2ff5-4a27-a2ff-0e2013083778", "tags": ["seq:step:1"]}, "data": {}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "name": "RunnableLambda", "run_id": "d9e0a1ec-2ff5-4a27-a2ff-0e2013083778", "tags": ["seq:step:1"]}, "data": {"chunk": {"text": "HELLO FROM SAIGON."}}}
# {"name": "on_chain_end", "type": null, "meta": {"event": "on_chain_end", "name": "RunnableLambda", "run_id": "d9e0a1ec-2ff5-4a27-a2ff-0e2013083778", "tags": ["seq:step:1"]}, "data": {"input": {"text": "Hello from Saigon."}, "output": {"text": "HELLO FROM SAIGON."}}}
# {"name": "on_prompt_start", "type": null, "meta": {"event": "on_prompt_start", "name": "ChatPromptTemplate", "run_id": "4bd252c0-720b-40b5-b6ae-cddf1523f83e", "tags": ["seq:step:2"]}, "data": {"input": {"text": "HELLO FROM SAIGON."}}}
# {"name": "on_prompt_end", "type": null, "meta": {"event": "on_prompt_end", "name": "ChatPromptTemplate", "run_id": "4bd252c0-720b-40b5-b6ae-cddf1523f83e", "tags": ["seq:step:2"]}, "data": {"input": {"text": "HELLO FROM SAIGON."}, "output": "ChatPromptValue(messages=[SystemMessage(content='You are a helpful assistant.', additional_kwargs={}, response_metadata=…"}}
# {"name": "on_chat_model_start", "type": null, "meta": {"event": "on_chat_model_start", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"input": {"messages": [["You are a helpful assistant.", "Translate to Vietnamese: HELLO FROM SAIGON."]]}}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": "X"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "X"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": "IN"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "IN"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": " CH"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " CH"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": "À"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "À"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": "O"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "O"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": " T"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " T"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": "Ừ"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "Ừ"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": " S"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " S"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": "À"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "À"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": "I"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "I"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": " G"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " G"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": "Ò"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "Ò"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": "N"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "N"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": ".\n\n"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": ".\n\n"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": "(Note"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "(Note"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": ":"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": ":"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": " \""}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " \""}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": "S"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "S"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": "ài"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "ài"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": " G"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " G"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": "òn"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "òn"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": "\""}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "\""}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": " is"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " is"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": " the"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " the"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": " Vietnamese"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " Vietnamese"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": " name"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " name"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": " for"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " for"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": " Sa"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " Sa"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": "igon"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "igon"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": ","}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": ","}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": " which"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " which"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": " was"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " was"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": " the"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " the"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": " former"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " former"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": " name"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " name"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": " of"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " of"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": " Ho"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " Ho"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": " Chi"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " Chi"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": " Minh"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " Minh"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": " City"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " City"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": ")"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": ")"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"chunk": ""}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": ""}}
# {"name": "on_chat_model_end", "type": null, "meta": {"event": "on_chat_model_end", "name": "ChatOllama", "run_id": "db84be0e-ff1d-4ae3-ab99-c2e119acdb59", "tags": ["seq:step:3"]}, "data": {"input": {"messages": [["You are a helpful assistant.", "Translate to Vietnamese: HELLO FROM SAIGON."]]}, "output": {"generations": [[{"text": "XIN CHÀO TỪ SÀI GÒN.\n\n(Note: \"Sài Gòn\" is the Vietnamese name for Saigon, which was the former name of Ho Chi Minh City)", "generation_info": {"model": "llama3.1:8b-instruct-q8_0", "created_at": "2025-08-19T12:32:17.666953Z", "done": true, "done_reason": "stop", "total_duration": 1262808916, "load_duration": 38482500, "prompt_eval_count": 32, "prompt_eval_duration": 102272584, "eval_count": 43, "eval_duration": 1121229625, "model_name": "llama3.1:8b-instruct-q8_0"}, "type": "ChatGenerationChunk", "message": "XIN CHÀO TỪ SÀI GÒN.\n\n(Note: \"Sài Gòn\" is the Vietnamese name for Saigon, which was the former name of Ho Chi Minh City)"}]], "llm_output": null, "run": null, "type": "LLMResult"}}}
# {"name": "on_chain_end", "type": null, "meta": {"event": "on_chain_end", "name": "RunnableSequence", "run_id": "5e5b69c6-3562-4603-8779-05d2f978630b", "tags": []}, "data": {"output": "XIN CHÀO TỪ SÀI GÒN.\n\n(Note: \"Sài Gòn\" is the Vietnamese name for Saigon, which was the former name of Ho Chi Minh City)"}}

# %% [markdown]
# #### Propagating Callbacks
#
# Small steps:
# 1) Write a small custom runnable that forwards callbacks
# 2) Compose it in a chain and observe events still flow
#
# Explanation:
# - Custom runnables should accept the `config` and pass `callbacks`/`tags` along to downstream components to preserve tracing and streaming.

# %%
from langchain_core.runnables import Runnable
from langchain_core.runnables.config import RunnableConfig

class ForwardCallbacks(Runnable):
    def invoke(self, input, config: RunnableConfig | None = None):
        # Do a tiny transform, but keep config to forward callbacks later
        text = input["text"].strip()
        return {"text": text}

forward = ForwardCallbacks()
cb_chain = forward | prompt | chat

async def events_with_forwarder():
    async for e in cb_chain.astream_events({"text": "  Please greet in Vietnamese.  "}, version="v1"):
        show_event(e)

await events_with_forwarder()
# Out:
# {"name": "on_chain_start", "type": null, "meta": {"event": "on_chain_start", "run_id": "0a9442a7-51be-46e6-a464-05a9c70adc4b", "name": "RunnableSequence", "tags": []}, "data": {"input": {"text": "  Please greet in Vietnamese.  "}}}
# {"name": "on_prompt_start", "type": null, "meta": {"event": "on_prompt_start", "name": "ChatPromptTemplate", "run_id": "21c29664-7e05-44d5-92e6-9c56d9951450", "tags": ["seq:step:2"]}, "data": {"input": {"text": "Please greet in Vietnamese."}}}
# {"name": "on_prompt_end", "type": null, "meta": {"event": "on_prompt_end", "name": "ChatPromptTemplate", "run_id": "21c29664-7e05-44d5-92e6-9c56d9951450", "tags": ["seq:step:2"]}, "data": {"input": {"text": "Please greet in Vietnamese."}, "output": "ChatPromptValue(messages=[SystemMessage(content='You are a helpful assistant.', additional_kwargs={}, response_metadata=…"}}
# {"name": "on_chat_model_start", "type": null, "meta": {"event": "on_chat_model_start", "name": "ChatOllama", "run_id": "909b85ed-e9d7-40c3-87ee-24f61dc7b4c8", "tags": ["seq:step:3"]}, "data": {"input": {"messages": [["You are a helpful assistant.", "Translate to Vietnamese: Please greet in Vietnamese."]]}}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "909b85ed-e9d7-40c3-87ee-24f61dc7b4c8", "tags": ["seq:step:3"]}, "data": {"chunk": "X"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "0a9442a7-51be-46e6-a464-05a9c70adc4b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "X"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "909b85ed-e9d7-40c3-87ee-24f61dc7b4c8", "tags": ["seq:step:3"]}, "data": {"chunk": "in"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "0a9442a7-51be-46e6-a464-05a9c70adc4b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "in"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "909b85ed-e9d7-40c3-87ee-24f61dc7b4c8", "tags": ["seq:step:3"]}, "data": {"chunk": " ch"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "0a9442a7-51be-46e6-a464-05a9c70adc4b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " ch"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "909b85ed-e9d7-40c3-87ee-24f61dc7b4c8", "tags": ["seq:step:3"]}, "data": {"chunk": "ào"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "0a9442a7-51be-46e6-a464-05a9c70adc4b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "ào"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "909b85ed-e9d7-40c3-87ee-24f61dc7b4c8", "tags": ["seq:step:3"]}, "data": {"chunk": "!"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "0a9442a7-51be-46e6-a464-05a9c70adc4b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "!"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "909b85ed-e9d7-40c3-87ee-24f61dc7b4c8", "tags": ["seq:step:3"]}, "data": {"chunk": " ("}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "0a9442a7-51be-46e6-a464-05a9c70adc4b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": " ("}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "909b85ed-e9d7-40c3-87ee-24f61dc7b4c8", "tags": ["seq:step:3"]}, "data": {"chunk": "Hello"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "0a9442a7-51be-46e6-a464-05a9c70adc4b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "Hello"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "909b85ed-e9d7-40c3-87ee-24f61dc7b4c8", "tags": ["seq:step:3"]}, "data": {"chunk": "!)"}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "0a9442a7-51be-46e6-a464-05a9c70adc4b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": "!)"}}
# {"name": "on_chat_model_stream", "type": null, "meta": {"event": "on_chat_model_stream", "name": "ChatOllama", "run_id": "909b85ed-e9d7-40c3-87ee-24f61dc7b4c8", "tags": ["seq:step:3"]}, "data": {"chunk": ""}}
# {"name": "on_chain_stream", "type": null, "meta": {"event": "on_chain_stream", "run_id": "0a9442a7-51be-46e6-a464-05a9c70adc4b", "tags": [], "name": "RunnableSequence"}, "data": {"chunk": ""}}
# {"name": "on_chat_model_end", "type": null, "meta": {"event": "on_chat_model_end", "name": "ChatOllama", "run_id": "909b85ed-e9d7-40c3-87ee-24f61dc7b4c8", "tags": ["seq:step:3"]}, "data": {"input": {"messages": [["You are a helpful assistant.", "Translate to Vietnamese: Please greet in Vietnamese."]]}, "output": {"generations": [[{"text": "Xin chào! (Hello!)", "generation_info": {"model": "llama3.1:8b-instruct-q8_0", "created_at": "2025-08-19T12:32:18.081608Z", "done": true, "done_reason": "stop", "total_duration": 396617458, "load_duration": 95900042, "prompt_eval_count": 30, "prompt_eval_duration": 86294584, "eval_count": 9, "eval_duration": 213592416, "model_name": "llama3.1:8b-instruct-q8_0"}, "type": "ChatGenerationChunk", "message": "Xin chào! (Hello!)"}]], "llm_output": null, "run": null, "type": "LLMResult"}}}
# {"name": "on_chain_end", "type": null, "meta": {"event": "on_chain_end", "name": "RunnableSequence", "run_id": "0a9442a7-51be-46e6-a464-05a9c70adc4b", "tags": []}, "data": {"output": "Xin chào! (Hello!)"}}

# %% [markdown]
# #### Working with Input Streams
#
# Small steps:
# 1) Create a `RunnableLambda` that accepts streamed input
# 2) Use `astream` to push input as an async generator
# 3) Show the model consuming partial input
#
# Explanation:
# - `astream` supports async iteration both for inputs and outputs.
# - This pattern is useful when your upstream UI produces partial input (e.g., speech-to-text).
